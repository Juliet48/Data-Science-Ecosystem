# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo">
# </center>

# %% [markdown]
# # Data Science Tools and Ecosystem

# %% [markdown]
#  Exploring Data Science tools and their ecosystem.

# %% [markdown]
# **Data scientists commonly use these programming languages:**
#
# 1. Python
# 2. R
# 3. SQL
# 4. Julia
# 5. Scala

# %% [markdown]
# **Data Scientists often rely on the following libraries:**
#
# 1. NumPy
# 2. Pandas
# 3. TensorFlow
# 4. PyTorch
# 5. Keras

# %% [markdown]
# |**Data Science Tools**|
# |------------------|
# |Jupyter Notebook|
# |RStudio|
# |Visual Studio Code (VSCode)|

# %% [markdown]
# ### Here are a few Python examples of evaluating mathematical equations

# %%
# This is a straightforward calculation involving multiplying and then adding whole numbers.

(3*4)+5
# Out:
# 17

# %%
# To find the equivalent of 200 minutes in hours, we divide the total minutes by 60.
m = 200
Minutes= m

h = (m/60)
Hours = h

print (h)
# Out:
# 3.3333333333333335

# %% [markdown]
# **Objectives:**
#
# - Data Science Libraries and Frameworks
# - Data Science Tools and Platforms
# - Common Data Science Algorithms
# - Data Science Languages

# %% [markdown]
# ## Author:
# Juliet Udeh
